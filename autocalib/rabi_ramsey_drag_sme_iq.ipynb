# %% [markdown]
# # musiq autocalib: Rabi / Ramsey / DRAG
#
# This notebook keeps only experiment-level code. The workflow execution, temporary config generation, and heterodyne I/Q integration statistics are handled by `ui.notebook` helpers.
#
# Config layout:
# - shared device: `device.yaml`
# - Rabi: `rabi/task.yaml`, `rabi/solver.yaml`, `rabi/pulse.yaml`, `rabi/analyser.yaml`
# - Ramsey: `ramsey/task.yaml`, `ramsey/solver.yaml`, `ramsey/pulse.yaml`, `ramsey/analyser.yaml`
# - DRAG: `drag/task.yaml`, `drag/solver.yaml`, `drag/pulse.yaml`, `drag/analyser.yaml`

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import numpy as np

ROOT = Path.cwd()
if not (ROOT / "src" / "musiq").exists():
    ROOT = next((p for p in Path.cwd().parents if (p / "src" / "musiq").exists()), Path.cwd())
sys.path.insert(0, str(ROOT / "src"))

from musiq.ui.notebook import (
    integrated_heterodyne_iq,
    integrated_iq_mean_error,
    plot_iq_cloud,
    plot_iq_clouds,
    run_param_sweep,
    run_pulse_sweep,
)

BASE = ROOT / "autocalib"
plt.rcParams.update({"figure.figsize": (7.0, 4.2), "axes.grid": True})

# %% [markdown]
# ## Rabi

# %%
from workflow import create_model

TASK_DIR = Path("rabi")
model = create_model(task_config=TASK_DIR / 'task.yaml')
model.run_all()
# Out:
# c:\Users\yijia\anaconda3\envs\musiq\Lib\site-packages\qutip\solver\multitrajresult.py:887: RuntimeWarning: overflow encountered in square
#   self.sum2_expect[i] += weight * expect_traj**2
# c:\Users\yijia\anaconda3\envs\musiq\Lib\site-packages\qutip\solver\multitrajresult.py:887: RuntimeWarning: invalid value encountered in multiply
#   self.sum2_expect[i] += weight * expect_traj**2
# 10.0%. Run time:   0.45s. Est. time left: 00:00:00:04
# 20.0%. Run time:   0.91s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.41s. Est. time left: 00:00:00:03
# 40.0%. Run time:   1.82s. Est. time left: 00:00:00:02
# 50.0%. Run time:   2.34s. Est. time left: 00:00:00:02
# 60.0%. Run time:   2.82s. Est. time left: 00:00:00:01
# 70.0%. Run time:   3.30s. Est. time left: 00:00:00:01
# 80.0%. Run time:   3.87s. Est. time left: 00:00:00:00
# 90.0%. Run time:   4.42s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.06s. Est. time left: 00:00:00:00
# Total run time:   5.09s

# %%
rabi_thetas = np.linspace(0.0, 2.0 * np.pi, 13)
rabi_cases = run_param_sweep(
    BASE / "rabi" / "task.yaml",
    "theta",
    rabi_thetas,
    generated_dir=BASE / "generated_configs" / "rabi",
    out_root=BASE / "runs" / "rabi",
    study_name="rabi_sme",
)

rabi_iq = integrated_iq_mean_error(rabi_cases)
fig, ax = plt.subplots()
ax.errorbar(rabi_thetas / np.pi, rabi_iq["mean"][:, 0], yerr=rabi_iq["error"][:, 0], fmt="o-", capsize=3, label="mean I")
ax.errorbar(rabi_thetas / np.pi, rabi_iq["mean"][:, 1], yerr=rabi_iq["error"][:, 1], fmt="s--", capsize=3, label="mean Q")
ax.set_xlabel("RX angle / pi")
# 60.0%. Run time:   2.91s. Est. time left: 00:00:00:01
# 70.0%. Run time:   3.49s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.12s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.72s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.41s. Est. time left: 00:00:00:00
# Total run time:   5.44s
# 10.0%. Run time:   0.49s. Est. time left: 00:00:00:04
# 20.0%. Run time:   0.97s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.52s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.04s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.54s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.09s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.62s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.17s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.73s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.38s. Est. time left: 00:00:00:00
# Total run time:   5.42s
# 10.0%. Run time:   0.55s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.07s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.68s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.20s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.68s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.14s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.68s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.21s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.74s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.34s. Est. time left: 00:00:00:00
# Total run time:   5.37s
# 10.0%. Run time:   0.47s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.03s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.61s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.10s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.57s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.01s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.50s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.03s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.54s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.04s. Est. time left: 00:00:00:00
# Total run time:   5.07s
# d:\閻℃帒鎳庨閬嶆煂韫囨挾鎽嶉悹渚婄磿閻ｅ寮甸崫鍕彣濠㈠湱澧楁慨鍌炲礆缁傜浂musiq\src\musiq\analysis\readout_chain.py:180: RuntimeWarning: overflow encountered in multiply
#   digital_baseband = 2.0 * adc_signal.astype(complex) * np.exp(
# d:\閻℃帒鎳庨閬嶆煂韫囨挾鎽嶉悹渚婄磿閻ｅ寮甸崫鍕彣濠㈠湱澧楁慨鍌炲礆缁傜浂musiq\src\musiq\analysis\readout_chain.py:180: RuntimeWarning: invalid value encountered in multiply
#   digital_baseband = 2.0 * adc_signal.astype(complex) * np.exp(
# 10.0%. Run time:   0.63s. Est. time left: 00:00:00:05
# 20.0%. Run time:   1.31s. Est. time left: 00:00:00:05
#   rf_signal = np.real(complex_envelope * np.exp(1j * (2.0 * math.pi * carrier_freq_hz * times + rf_phase)))
# d:\閻℃帒鎳庨閬嶆煂韫囨挾鎽嶉悹渚婄磿閻ｅ寮甸崫鍕彣濠㈠湱澧楁慨鍌炲礆缁傜浂musiq\src\musiq\analysis\readout_chain.py:161: RuntimeWarning: invalid value encountered in multiply
#   rf_signal_adc = np.real(envelope_adc * np.exp(1j * (2.0 * math.pi * carrier_freq_hz * adc_times + rf_phase)))
# d:\閻℃帒鎳庨閬嶆煂韫囨挾鎽嶉悹渚婄磿閻ｅ寮甸崫鍕彣濠㈠湱澧楁慨鍌炲礆缁傜浂musiq\src\musiq\analysis\readout_chain.py:167: RuntimeWarning: invalid value encountered in multiply
#   if_signal = np.real(complex_envelope * np.exp(1j * (2.0 * math.pi * if_frequency_hz * times + if_phase)))
# d:\閻℃帒鎳庨閬嶆煂韫囨挾鎽嶉悹渚婄磿閻ｅ寮甸崫鍕彣濠㈠湱澧楁慨鍌炲礆缁傜浂musiq\src\musiq\analysis\readout_chain.py:168: RuntimeWarning: invalid value encountered in multiply
#   if_signal_adc = np.real(envelope_adc * np.exp(1j * (2.0 * math.pi * if_frequency_hz * adc_times + if_phase)))
# 10.0%. Run time:   0.48s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.05s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.58s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.09s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.56s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.07s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.57s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.01s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.51s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.12s. Est. time left: 00:00:00:00
# Total run time:   5.17s

# %%
fig, ax = plt.subplots(figsize=(6.2, 5.0), constrained_layout=True)
plot_iq_clouds(ax, [rabi_cases[idx] for idx in [0, 3, 6]], "Rabi integrated I/Q")

# %% [markdown]
# ## Ramsey

# %%
ramsey_phis = np.linspace(0.0, 2.0 * np.pi, 13)
ramsey_cases = run_param_sweep(
    BASE / "ramsey" / "task.yaml",
    "phi",
    ramsey_phis,
    generated_dir=BASE / "generated_configs" / "ramsey",
    out_root=BASE / "runs" / "ramsey",
    study_name="ramsey_sme",
)

ramsey_iq = integrated_iq_mean_error(ramsey_cases)
fig, ax = plt.subplots()
ax.errorbar(ramsey_phis / np.pi, ramsey_iq["mean"][:, 0], yerr=ramsey_iq["error"][:, 0], fmt="o-", capsize=3, label="mean I")
ax.errorbar(ramsey_phis / np.pi, ramsey_iq["mean"][:, 1], yerr=ramsey_iq["error"][:, 1], fmt="s--", capsize=3, label="mean Q")
ax.set_xlabel("Ramsey phase / pi")
ax.set_ylabel("integrated I/Q")
ax.set_title("Ramsey readout from musiq heterodyne SME")
ax.legend();
# Out:
# 10.0%. Run time:   0.51s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.06s. Est. time left: 00:00:00:04
# 70.0%. Run time:   4.07s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.62s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.17s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.73s. Est. time left: 00:00:00:00
# Total run time:   5.76s
# 10.0%. Run time:   0.51s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.05s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.67s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.21s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.76s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.29s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.93s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.48s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.99s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.59s. Est. time left: 00:00:00:00
# Total run time:   5.61s
# 10.0%. Run time:   0.58s. Est. time left: 00:00:00:05
# 20.0%. Run time:   1.19s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.76s. Est. time left: 00:00:00:04
# 40.0%. Run time:   2.30s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.86s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.44s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.99s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.55s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.14s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.74s. Est. time left: 00:00:00:00
# Total run time:   5.77s
# 10.0%. Run time:   0.51s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.05s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.68s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.22s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.78s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.36s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.93s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.52s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.07s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.63s. Est. time left: 00:00:00:00
# Total run time:   5.66s
# d:\閻℃帒鎳庨閬嶆煂韫囨挾鎽嶉悹渚婄磿閻ｅ寮甸崫鍕彣濠㈠湱澧楁慨鍌炲礆缁傜浂musiq\src\musiq\ui\notebook.py:330: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(points, axis=0)
# c:\Users\yijia\anaconda3\envs\musiq\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
fig, ax = plt.subplots(figsize=(6.2, 5.0), constrained_layout=True)
plot_iq_clouds(ax, [ramsey_cases[idx] for idx in [0, len(ramsey_cases) // 2, -1]], "Ramsey integrated I/Q")

# %% [markdown]
# ## DRAG

# %%
drag_betas = np.linspace(-1.0, 1.0, 11)
drag_cases = run_pulse_sweep(
    BASE / "drag" / "task.yaml",
    "single_qubit_drag_beta",
    drag_betas,
    generated_dir=BASE / "generated_configs" / "drag",
    out_root=BASE / "runs" / "drag",
    study_name="drag_sme",
)

drag_iq = integrated_iq_mean_error(drag_cases)
best_idx = int(np.nanargmax(np.linalg.norm(drag_iq["mean"], axis=1)))
fig, ax = plt.subplots()
ax.errorbar(drag_betas, drag_iq["mean"][:, 0], yerr=drag_iq["error"][:, 0], fmt="o-", capsize=3, label="mean I")
ax.errorbar(drag_betas, drag_iq["mean"][:, 1], yerr=drag_iq["error"][:, 1], fmt="s--", capsize=3, label="mean Q")
ax.axvline(drag_betas[best_idx], color="black", lw=1.0, alpha=0.6)
ax.set_xlabel("DRAG beta")
ax.set_ylabel("integrated I/Q")
ax.set_title("DRAG readout from musiq heterodyne SME")
ax.legend();
print(f"largest readout response beta={drag_betas[best_idx]:.3f}, shots={drag_iq['n'][best_idx]}")
# Out:
# 10.0%. Run time:   0.47s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.01s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.53s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.09s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.68s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.22s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.77s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.38s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.99s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.61s. Est. time left: 00:00:00:00
# Total run time:   5.64s
# 10.0%. Run time:   0.51s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.02s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.63s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.20s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.80s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.35s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.86s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.41s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.08s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.60s. Est. time left: 00:00:00:00
# Total run time:   5.62s
# 10.0%. Run time:   0.52s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.06s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.65s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.22s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.75s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.27s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.86s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.39s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.94s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.56s. Est. time left: 00:00:00:00
# Total run time:   5.59s
# 10.0%. Run time:   0.54s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.08s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.75s. Est. time left: 00:00:00:04
# 40.0%. Run time:   2.28s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.84s. Est. time left: 00:00:00:02
# 30.0%. Run time:   2.00s. Est. time left: 00:00:00:04
# 40.0%. Run time:   2.60s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.23s. Est. time left: 00:00:00:03
# 60.0%. Run time:   3.82s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.40s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.98s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.48s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.97s. Est. time left: 00:00:00:00
# Total run time:   6.00s
# 10.0%. Run time:   0.55s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.08s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.58s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.14s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.73s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.29s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.83s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.44s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.99s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.52s. Est. time left: 00:00:00:00
# Total run time:   5.55s
# 10.0%. Run time:   0.52s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.11s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.66s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.24s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.75s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.24s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.85s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.42s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.92s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.42s. Est. time left: 00:00:00:00
# Total run time:   5.46s
# largest readout response beta=0.800, shots=200

# %%
fig, ax = plt.subplots(figsize=(6.2, 5.0), constrained_layout=True)
plot_iq_clouds(ax, [drag_cases[idx] for idx in [0, best_idx, -1]], "DRAG integrated I/Q")

# %% [markdown]
# ## Payload check

# %%
sample = drag_cases[best_idx]
tr = sample["trajectory"]
print("output dir:", sample["out_dir"])
print("engine:", tr.engine)
print("solver_impl:", tr.metadata.get("solver_impl"))
print("readout_protocol:", tr.metadata.get("readout_protocol"))
print("measurement records:", len((tr.measurements or {}).get("records", [])))
print("integrated I/Q points:", integrated_heterodyne_iq(sample).shape)
stats = integrated_iq_mean_error([sample])
print("integrated I/Q mean:", stats["mean"][0])
print("integrated I/Q errorbar (SEM):", stats["error"][0])
# Out:
# output dir: D:\閻℃帒鎳庨閬嶆煂韫囨挾鎽嶉悹渚婄磿閻ｅ寮甸崫鍕彣濠㈠湱澧楁慨鍌炲礆缁傜浂musiq\autocalib\runs\drag\single_qubit_drag_beta_09
# engine: qutip
# solver_impl: smesolve
# readout_protocol: heterodyne_sme
# measurement records: 200
# integrated I/Q points: (200, 2)
# integrated I/Q mean: [8257.79995237 -232.18630379]
# integrated I/Q errorbar (SEM): [247.10836311 224.130078  ]
